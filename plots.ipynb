# %%
import numpy as np


from bs4 import BeautifulSoup
import pandas as pd
import requests
import datetime
import seaborn 

name_csv = 'output/data.csv'
df = pd.read_csv(name_csv)

df['date'] = df['date'].astype('datetime64[s]')
df['grade'] = df['grade'].astype('string')
df['name'] = df['name'].astype('string')
df['station'] = df['station'].astype('string')

# %%
df = df.sort_values(by='date')

# %%
df.date.plot()
# Out:
# <Axes: >

# %%
from matplotlib import pyplot as plt

plt.scatter(df.date.values, np.arange(df.date.values.shape[0]))

# %%
fig = plt.figure(figsize = (18,5))
#plt.scatter(df.date.values[df.date.dt.year > 1990], np.ones(df.date.values.shape[0]))

filt = df[df.date.dt.year > 1990]
plt.scatter(filt.date.values, np.ones(filt.values.shape[0]))

# %%
# Out:
#           date          grade                             name  \
# 299 1991-01-22      Cabo 2do.         Waldo David Osorio Reyes
# 298 1991-01-24     Carabinero  Manuel Humberto Miranda Barrera
# 297 1991-02-28     Carabinero    Osvaldo Francisco Reyes Reyes
# 296 1991-03-27       Capitán     Fermín Roberto Guiñez Naudón
# 295 1991-04-04      Cabo 2do.       Agustín Adolfo Medel Barra
# ..         ...            ...                              ...
# 5   2022-10-10      Cabo 1ro.   Gastón Antonio Hermosilla Saez
# 4   2022-10-11  Sargento 2do.             Carlos Retamal Jaque
# 3   2023-03-14      Cabo 1ro.   Álex Onésimo Salazar Rodríguez
# 2   2023-03-26  Sargento 2do.               Rita Olivares Raio
# 1   2023-04-06      Cabo 1ro.               Daniel Palma Yáñez
#
#                         station
# 299   4a. Com. Tránsito Concep.
# 298           5a. Com. Conchalí
# 297              7a. Com. Renca
# 296    42a. Com. Radiopatrullas
# 295         7a. Com. Villarrica
# ...

# %%
filt = df[df.date.dt.year > 2009]

fig, ax = plt.subplots(figsize=(12,6))
sns.countplot(data=filt, x = filt.date.dt.year, color = 'k')

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.grid()
plt.tight_layout()
plt.savefig('2010.svg')

# %%
fig, ax = plt.subplots(figsize=(12,6))
sns.countplot(data=df, x = df.date.dt.year, color = 'k', order = list(range(1927,2023)))

plt.grid()
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.savefig('allData.svg')

# %%
first_year = 1967

filt = df[df.date.dt.year > first_year]

fig, ax = plt.subplots(figsize=(12,6))
sns.countplot(data=filt, x = filt.date.dt.year, color = 'k', order = list(range(first_year, 2024)))

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.grid()
plt.tight_layout()
plt.savefig('1967.svg')

# %%
filt = df[df.date.dt.year > 1990]

fig, ax = plt.subplots(figsize=(12,6))
sns.countplot(data=filt, x = filt.date.dt.month, color = 'k')

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.grid()
plt.tight_layout()
plt.savefig('2010.svg')
